# %% [markdown]
# <a href="https://colab.research.google.com/github/AlifaNurHafizhah001/Latihan_Naive-Bayes_Sistem-Cerdas/blob/main/Alifa_Tugas_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac02a267-a8e4-497d-bab9-c74658fcd5b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac02a267-a8e4-497d-bab9-c74658fcd5b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_excel('shooping_demo.xls')
data.head()
# Out:
#        Day Discount Free Delivery  Buy
# 0  Weekday      Yes           Yes  Yes
# 1  Weekday      Yes           Yes  Yes
# 2  Weekend       No            No   No
# 3  Holiday      Yes           Yes  Yes
# 4  Weekday      Yes           Yes  Yes

# %%
data.shape
# Out:
# (50, 4)

# %%
data['Buy'].value_counts()
# Out:
# Buy
# Yes    41
# No      9
# Name: count, dtype: int64

# %%
PYes = 41/50
PNo = 9/50

# %%
print(PYes)
# Out:
# 0.82

# %%
print(PNo)
# Out:
# 0.18

# %%
pd.crosstab(data['Day'], data['Buy'])
# Out:
# Buy      No  Yes
# Day
# Holiday   6   18
# Weekday   2    9
# Weekend   1   14

# %%
BHolidayNo = 6/9
BWeekdayNo = 2/9
BWeekendNo = 1/9

BHolidayYes = 18/41
BWeekdayYes = 9/41
BWeekendYes = 14/41

BHoliday = 24/50
BWeekday = 11/50
BWeekend = 15/50
BNo = 9/50
BYes = 41/50  # Probabilitas tidak membeli

print (BWeekdayYes)
# Out:
# 0.21951219512195122

# %%
# P(A|B) ?
# P (B) = BWeekday
# P (A) = No Buy
# P(B|A) = B Weekday|NoBuy

# %%
BNoWeekday = (BWeekdayNo*BNo)/BWeekday
print (BNoWeekday)
# Out:
# 0.1818181818181818

# %%
BYesWeekday = (BWeekdayYes*BYes)/BWeekday
print (BYesWeekday)
# Out:
# 0.8181818181818181

# %%
# Probabilitas (Buy | Weekday) > dibanding dengan Probabilitas (NoBuy | Weekday)
print(BNoWeekday)
print(BYesWeekday)
# Out:
# 0.1818181818181818
# 0.8181818181818181

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# A = Buy
# P(A|B) = B(NoBuy|DiscountYes, Free Delivery Yes, BDayHoliday)

# %%
pd.crosstab(data['Discount'], data['Buy'])
# Out:
# Buy       No  Yes
# Discount
# No         5   12
# Yes        4   29

# %%
BNoDiscountNo = 5/9
BYesDiscountNo = 4/9

BNoDiscountYes = 12/41
BYesDiscountYes = 29/41

BNoDiscount = 17/50
BYesDiscount = 33/50

# %%
pd.crosstab(data['Free Delivery'], data['Buy'])
# Out:
# Buy            No  Yes
# Free Delivery
# No              4   10
# Yes             5   31

# %%
BNoDeliveryNo = 4/9
BYesDeliveryNo = 5/9

BNoDeliveryYes = 10/41
BYesDeliveryYes = 31/41

BNoDelivery = 14/50
BYesDelivery = 36/50

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# P(A) = NoBuy = BNo
# P(B) = BYesDiscount,BYesDelivery,BHoliday
# P(B|A)1 = (BHoliday|No Buy) = BHolidayNo
# P(B|A)2 = (BYesDiscount|No Buy) = BYesDiscountNo
# P(B|A)3 = (BYesDelivery|No Buy) = BYesDeliveryNo
# P(B)1 = BHoliday
# P(B)2 = BYesDiscount
# P(B)3 = BYesDelivery

#ditanyakan P(A|B) ?
#Rumus
# P(A|B) = P(B|A)*P(A)/P(B)

# %%
BNoBuy1 = ((BHolidayNo*BYesDiscountNo*BYesDeliveryNo)*BNo)/(BHoliday*BYesDiscount*BYesDelivery)
print(BNoBuy1)
# Out:
# 0.12989982125784594

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# P(A) = Buy = BYes
# P(B) = BYesDiscount,BYesDelivery,BHoliday
# P(B|A)1 = (BHoliday|Buy) = BHolidayYes
# P(B|A)2 = (BYesDiscount|Buy) = BYesDiscountYes
# P(B|A)3 = (BYesDelivery|Buy) = BYesDeliveryYes
# P(B)1 = BHoliday
# P(B)2 = BYesDiscount
# P(B)3 = BYesDelivery

#ditanyakan P(A|B) ?
#Rumus
# P(A|B) = P(B|A)*P(A)/P(B)

# %%
BBuy2 = ((BHolidayYes*BYesDiscountYes*BYesDeliveryYes)*BYes)/(BHoliday*BYesDiscount*BYesDelivery)
print(BBuy2)
# Out:
# 0.8440667832398943

# %%
# probability of No Buy = 0.12989982125784594
# probability Buy = 0.8440667832398943

# %%
BSum = BNoBuy1+BBuy2
print(BSum)
# Out:
# 0.9739666044977402

# %%
BBuy = (BBuy2/BSum) *100
print(BBuy)
# Out:
# 86.66280541263185

# %%
BNoBuy = (BNoBuy1*BSum) *100
print(BNoBuy)
# Out:
# 12.651808783536758

# %%
# Tambahan data Weekday dan Weekend
BWeekdayNo = 2/9
BWeekendNo = 1/9

BWeekdayYes = 9/41
BWeekendYes = 14/41

BWeekday = 11/50
BWeekend = 15/50

# Discount
BNoDiscountNo = 5/9
BYesDiscountNo = 4/9
BNoDiscountYes = 5/41
BYesDiscountYes = 29/41
BNoDiscount = 17/50
BYesDiscount = 33/50

# Free Delivery
BNoDeliveryNo = 4/9
BYesDeliveryNo = 5/9
BNoDeliveryYes = 10/41
BYesDeliveryYes = 31/41
BNoDelivery = 14/50
BYesDelivery = 36/50

# Prior probabilities
BYes = 41/50
BNo = 9/50

# %%
# a. P(Buy | Weekday, Free Delivery = Yes, Discount = Yes)
PBuy_a = ((BWeekdayYes * BYesDeliveryYes * BYesDiscountYes) * BYes) / (BWeekday * BYesDelivery * BYesDiscount)
print("a. P(Buy | Weekday, FreeDelivery=Yes, Discount=Yes) =", PBuy_a)
# Out:
# a. P(Buy | Weekday, FreeDelivery=Yes, Discount=Yes) = 0.9208001271707938

# %%
# b. P(Buy | Weekday, Free Delivery = No, Discount = No)
PBuy_b = ((BWeekdayYes * BNoDeliveryYes * BNoDiscountYes) * BYes) / (BWeekday * BNoDelivery * BNoDiscount)
print("b. P(Buy | Weekday, FreeDelivery=No, Discount=No) =", PBuy_b)
# Out:
# b. P(Buy | Weekday, FreeDelivery=No, Discount=No) = 0.25563196994767834

# %%
# c. P(Not Buy | Weekday, Free Delivery = Yes, Discount = Yes)
PNoBuy_c = ((BWeekdayNo * BYesDeliveryNo * BYesDiscountNo) * BNo) / (BWeekday * BYesDelivery * BYesDiscount)
print("c. P(NotBuy | Weekday, FreeDelivery=Yes, Discount=Yes) =", PNoBuy_c)
# Out:
# c. P(NotBuy | Weekday, FreeDelivery=Yes, Discount=Yes) = 0.0944725972784334

# %%
# d. P(Not Buy | Weekday, Free Delivery = No, Discount = No)
PNoBuy_d = ((BWeekdayNo * BNoDeliveryNo * BNoDiscountNo) * BNo) / (BWeekday * BNoDelivery * BNoDiscount)
print("d. P(NotBuy | Weekday, FreeDelivery=No, Discount=No) =", PNoBuy_d)
# Out:
# d. P(NotBuy | Weekday, FreeDelivery=No, Discount=No) = 0.4715690990200793

# %%
# e. P(Buy | Weekend, Free Delivery = Yes, Discount = Yes)
PBuy_e = ((BWeekendYes * BYesDeliveryYes * BYesDiscountYes) * BYes) / (BWeekend * BYesDelivery * BYesDiscount)
print("e. P(Buy | Weekend, FreeDelivery=Yes, Discount=Yes) =", PBuy_e)
# Out:
# e. P(Buy | Weekend, FreeDelivery=Yes, Discount=Yes) = 1.0503942191429798

# %%
# f. P(Buy | Weekend, Free Delivery = No, Discount = No)
PBuy_f = ((BWeekendYes * BNoDeliveryYes * BNoDiscountYes) * BYes) / (BWeekend * BNoDelivery * BNoDiscount)
print("f. P(Buy | Weekend, FreeDelivery=No, Discount=No) =", PBuy_f)
# Out:
# f. P(Buy | Weekend, FreeDelivery=No, Discount=No) = 0.2916098027551293

# %%
# g. P(Not Buy | Weekend, Free Delivery = Yes, Discount = Yes)
PNoBuy_g = ((BWeekendNo * BYesDeliveryNo * BYesDiscountNo) * BNo) / (BWeekend * BYesDelivery * BYesDiscount)
print("g. P(NotBuy | Weekend, FreeDelivery=Yes, Discount=Yes) =", PNoBuy_g)
# Out:
# g. P(NotBuy | Weekend, FreeDelivery=Yes, Discount=Yes) = 0.034639952335425585

# %%
# h. P(Not Buy | Weekend, Free Delivery = No, Discount = No)
PNoBuy_h = ((BWeekendNo * BNoDeliveryNo * BNoDiscountNo) * BNo) / (BWeekend * BNoDelivery * BNoDiscount)
print("h. P(NotBuy | Weekend, FreeDelivery=No, Discount=No) =", PNoBuy_h)
# Out:
# h. P(NotBuy | Weekend, FreeDelivery=No, Discount=No) = 0.17290866964069576
